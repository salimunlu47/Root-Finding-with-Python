# %% [markdown]
# # Root Finding

# %% [markdown]
# Core objective is to translate an objective into an algorithm and then into an implementation in Python

# %%
import math
import functions

#f(x)=sinx Bisection Method on [3.0,4.0]
functions.bisection(functions.f3, 3.0, 4.0, 1e-8)

#f(x)=sinx Newton’s Method with x0 = 4.0
functions.newtons(functions.f3, functions.f3_prime, 4.0, 1e-8)

#f(x)=x^7-3 Bisection Method on [1.0,1.5]
functions.bisection(functions.f4, 1.0, 1.5, 1e-8)

#f(x)=x^7-3 Newton’s Method with x0 = 1.5
functions.newtons(functions.f4, functions.f4_prime, 1.5, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Bisection Method on [-3.0,-2.0]
functions.bisection(functions.f5, -3.0, -2.0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Bisection Method on [-2.0, 0]
functions.bisection(functions.f5, -2.0, 0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Bisection Method on [0, 1.0]
functions.bisection(functions.f5, 0.0, 1.0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Bisection Method on [1.0, 3.0]
functions.bisection(functions.f5, 1.0, 3.0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Bisection Method on [-3.0, 1.5]
functions.bisection(functions.f5, -3.0, 1.5, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Bisection Method on [-3.0, 3.0]
functions.bisection(functions.f5, -3.0, 3.0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Newton’s Method with x0 = -3.0
functions.newtons(functions.f5, functions.f5_prime, -3.0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Newton’s Method with x0 = -2.0
functions.newtons(functions.f5, functions.f5_prime, -2.0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Newton’s Method with x0 = -1.5
functions.newtons(functions.f5, functions.f5_prime, -1.5, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Newton’s Method with x0 = 0
functions.newtons(functions.f5, functions.f5_prime, 0, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Newton’s Method with x0 = 0.5
functions.newtons(functions.f5, functions.f5_prime, 0.5, 1e-8)

#f5(x)=x^3+2x^2-3x-1 Newton’s Method with x0 = 1.5
functions.newtons(functions.f5, functions.f5_prime, 1.5, 1e-8)

#f6(x)=(e^x-e^(-x))/(e^x+e^(-x)) Bisection Method on [-2.0, 2.0]
functions.bisection(functions.f6, -2.0, 2.0, 1e-8)

#f6(x)=(e^x-e^(-x))/(e^x+e^(-x)) Newton’s Method with x0 = 1.0
functions.newtons(functions.f6, functions.f6_prime, 1.0, 1e-8)

#f6(x)=(e^x-e^(-x))/(e^x+e^(-x)) Newton’s Method with x0 = 1.1
functions.newtons(functions.f6, functions.f6_prime, 1.1, 1e-8)

#f7(x) Bisection Method on [0.01, 0.1]
functions.bisection(functions.f7, 0.01, 0.1, 5e-6)

#f8(x) Bisection Method on [0.01, 0.1]
functions.bisection(functions.f8, 0.01, 0.1, 5e-6)
# Out:
# running bisection with arguments <function f3 at 0x000001EF57E80DC8>, 3.000000, 4.000000, 0.000000
# x0=3.500000000, low=3.000000000, high=4.000000000, e0=0.500000000
# x1=3.250000000, low=3.000000000, high=3.500000000, e1=0.250000000
# x2=3.125000000, low=3.000000000, high=3.250000000, e2=0.125000000
# x3=3.187500000, low=3.125000000, high=3.250000000, e3=0.062500000
# x4=3.156250000, low=3.125000000, high=3.187500000, e4=0.031250000
# x5=3.140625000, low=3.125000000, high=3.156250000, e5=0.015625000
# x6=3.148437500, low=3.140625000, high=3.156250000, e6=0.007812500
# x7=3.144531250, low=3.140625000, high=3.148437500, e7=0.003906250
# x8=3.142578125, low=3.140625000, high=3.144531250, e8=0.001953125
# x9=3.141601562, low=3.140625000, high=3.142578125, e9=0.000976562
# x10=3.141113281, low=3.140625000, high=3.141601562, e10=0.000488281
# x11=3.141357422, low=3.141113281, high=3.141601562, e11=0.000244141
# x12=3.141479492, low=3.141357422, high=3.141601562, e12=0.000122070
# ...
